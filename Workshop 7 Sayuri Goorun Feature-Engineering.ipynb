# %% [markdown]
# # Feature Engineering
#
# Feature Engineering is the process of transforming raw data into meaningful features that can be used as input for advanceced visualisations or machine learning algorithms.
#
# It involves selecting, creating, and transforming features to hopefully enhance the dataset.
#
# Poorly designed features can lead to a disruptive dataset.

# %% [markdown]
# ## Types of Feature Engineering
#
# * **Handling Missing Values**
#
#     Filling missing values with appropriate strategies, e.g., mean, median, or constant values.
#
# * **Encoding Categorical Variables**
#
#     Converting categorical data into numeric form, such as one-hot encoding or label encoding. Only needed if you are building a model
#
# * **Binning Numeric Variables**
#
#     Grouping continuous data into bins or categories to simplify the representation.
#
# * **Feature Scaling**
#
#     Scaling features to bring them to a similar range, e.g., Min-Max scaling or Standard scaling.
#
# * **Creating New Features**
#
#     Generating new features by combining or transforming existing ones.
#
# * **Handling Outliers**
#
#     Managing extreme values that can affect model performance.
#
# * **Feature Joining**
#
#     Creating new features by combining multiple existing features.

# %% [markdown]
# ## Imports and Dataset

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("insurance_claims.csv")

# %%
df.head()
# Out:
#    months_as_customer  age  policy_number policy_bind_date policy_state  \
# 0                 328   48         521585       2014-10-17           OH
# 1                 228   42         342868       2006-06-27           IN
# 2                 134   29         687698       2000-09-06           OH
# 3                 256   41         227811       1990-05-25           IL
# 4                 228   44         367455       2014-06-06           IL
#
#   policy_csl  policy_deductable  policy_annual_premium  umbrella_limit  \
# 0    250/500               1000                1406.91               0
# 1    250/500               2000                1197.22         5000000
# 2    100/300               2000                1413.14         5000000
# 3    250/500               2000                1415.74         6000000
# 4   500/1000               1000                1583.91         6000000
#
#    insured_zip  ... police_report_available total_claim_amount injury_claim  \
# ...

# %%
df.columns
# Out:
# Index(['months_as_customer', 'age', 'policy_number', 'policy_bind_date',
#        'policy_state', 'policy_csl', 'policy_deductable',
#        'policy_annual_premium', 'umbrella_limit', 'insured_zip', 'insured_sex',
#        'insured_education_level', 'insured_occupation', 'insured_hobbies',
#        'insured_relationship', 'capital-gains', 'capital-loss',
#        'incident_date', 'incident_type', 'collision_type', 'incident_severity',
#        'authorities_contacted', 'incident_state', 'incident_city',
#        'incident_location', 'incident_hour_of_the_day',
#        'number_of_vehicles_involved', 'property_damage', 'bodily_injuries',
#        'witnesses', 'police_report_available', 'total_claim_amount',
#        'injury_claim', 'property_claim', 'vehicle_claim', 'auto_make',
#        'auto_model', 'auto_year', 'fraud_reported', '_c39'],
#       dtype='object')

# %% [markdown]
# ### Missing Values

# %%
null_counts = df.isnull().sum()
null_counts
# Out:
# months_as_customer                0
# age                               0
# policy_number                     0
# policy_bind_date                  0
# policy_state                      0
# policy_csl                        0
# policy_deductable                 0
# policy_annual_premium             0
# umbrella_limit                    0
# insured_zip                       0
# insured_sex                       0
# insured_education_level           0
# insured_occupation                0
# insured_hobbies                   0
# insured_relationship              0
# capital-gains                     0
# capital-loss                      0
# incident_date                     0
# incident_type                     0
# collision_type                    0
# incident_severity                 0
# authorities_contacted             0
# incident_state                    0
# incident_city                     0
# incident_location                 0
# incident_hour_of_the_day          0
# ...

# %%
df_new = df.drop("_c39", axis = 1)

# %%
df_new.head()
# Out:
#    months_as_customer  age  policy_number policy_bind_date policy_state  \
# 0                 328   48         521585       2014-10-17           OH
# 1                 228   42         342868       2006-06-27           IN
# 2                 134   29         687698       2000-09-06           OH
# 3                 256   41         227811       1990-05-25           IL
# 4                 228   44         367455       2014-06-06           IL
#
#   policy_csl  policy_deductable  policy_annual_premium  umbrella_limit  \
# 0    250/500               1000                1406.91               0
# 1    250/500               2000                1197.22         5000000
# 2    100/300               2000                1413.14         5000000
# 3    250/500               2000                1415.74         6000000
# 4   500/1000               1000                1583.91         6000000
#
#    insured_zip  ... witnesses police_report_available total_claim_amount  \
# ...

# %% [markdown]
# ### Binding Numeric Data

# %%
df_new.describe()
# Out:
#        months_as_customer          age  policy_number  policy_deductable  \
# count         1000.000000  1000.000000    1000.000000        1000.000000
# mean           203.954000    38.948000  546238.648000        1136.000000
# std            115.113174     9.140287  257063.005276         611.864673
# min              0.000000    19.000000  100804.000000         500.000000
# 25%            115.750000    32.000000  335980.250000         500.000000
# 50%            199.500000    38.000000  533135.000000        1000.000000
# 75%            276.250000    44.000000  759099.750000        2000.000000
# max            479.000000    64.000000  999435.000000        2000.000000
#
#        policy_annual_premium  umbrella_limit    insured_zip  capital-gains  \
# count            1000.000000    1.000000e+03    1000.000000    1000.000000
# mean             1256.406150    1.101000e+06  501214.488000   25126.100000
# std               244.167395    2.297407e+06   71701.610941   27872.187708
# ...

# %%
# Choose the column for the histogram
column_name = 'age'

# Plot the histogram
plt.hist(df[column_name], bins=3, edgecolor='black')

# Add labels and title
plt.xlabel(column_name)
plt.ylabel('Frequency')
plt.title(f'Histogram of {column_name}')

# Display the histogram
plt.show()

# %%
bin_edges = [0, 30, 55, 100]  # Define the bin edges
bin_labels = ['Young Adult', 'Middle Aged', 'Elderly']  # Corresponding labels for each bin

# Create a new column based on the bin labels
df_new['ages_category'] = pd.cut(df_new['age'], bins=bin_edges, labels=bin_labels)

# %%
df_new.head()
# Out:
#    months_as_customer  age  policy_number policy_bind_date policy_state  \
# 0                 328   48         521585       2014-10-17           OH
# 1                 228   42         342868       2006-06-27           IN
# 2                 134   29         687698       2000-09-06           OH
# 3                 256   41         227811       1990-05-25           IL
# 4                 228   44         367455       2014-06-06           IL
#
#   policy_csl  policy_deductable  policy_annual_premium  umbrella_limit  \
# 0    250/500               1000                1406.91               0
# 1    250/500               2000                1197.22         5000000
# 2    100/300               2000                1413.14         5000000
# 3    250/500               2000                1415.74         6000000
# 4   500/1000               1000                1583.91         6000000
#
#    insured_zip  ... police_report_available total_claim_amount injury_claim  \
# ...

# %%
bin_edges_customer = [0, 25, 150, 500]  # Define the bin edges
bin_labels_customer = ['New Client', 'Established Client', 'Long-Term Client']  # Corresponding labels for each bin

# Create a new column based on the bin labels
df_new['customer_category'] = pd.cut(df_new['months_as_customer'], bins=bin_edges_customer, labels=bin_labels_customer)

# %%
df_new.head()
# Out:
#    months_as_customer  age  policy_number policy_bind_date policy_state  \
# 0                 328   48         521585       2014-10-17           OH
# 1                 228   42         342868       2006-06-27           IN
# 2                 134   29         687698       2000-09-06           OH
# 3                 256   41         227811       1990-05-25           IL
# 4                 228   44         367455       2014-06-06           IL
#
#   policy_csl  policy_deductable  policy_annual_premium  umbrella_limit  \
# 0    250/500               1000                1406.91               0
# 1    250/500               2000                1197.22         5000000
# 2    100/300               2000                1413.14         5000000
# 3    250/500               2000                1415.74         6000000
# 4   500/1000               1000                1583.91         6000000
#
#    insured_zip  ... total_claim_amount injury_claim property_claim  \
# ...

# %% [markdown]
# ## Creating New Features

# %%
df_new["Contract Years"] = df_new["months_as_customer"]/12

# %%
df_new.head()
# Out:
#    months_as_customer  age  policy_number policy_bind_date policy_state  \
# 0                 328   48         521585       2014-10-17           OH
# 1                 228   42         342868       2006-06-27           IN
# 2                 134   29         687698       2000-09-06           OH
# 3                 256   41         227811       1990-05-25           IL
# 4                 228   44         367455       2014-06-06           IL
#
#   policy_csl  policy_deductable  policy_annual_premium  umbrella_limit  \
# 0    250/500               1000                1406.91               0
# 1    250/500               2000                1197.22         5000000
# 2    100/300               2000                1413.14         5000000
# 3    250/500               2000                1415.74         6000000
# 4   500/1000               1000                1583.91         6000000
#
#    insured_zip  ... injury_claim property_claim vehicle_claim  auto_make  \
# ...

# %% [markdown]
# ## Feature Joining

# %%
df_new['total_premiums_paid'] = (df_new['policy_annual_premium']/12) * df_new['months_as_customer']

# %%
df_new.head()
# Out:
#    months_as_customer  age  policy_number policy_bind_date policy_state  \
# 0                 328   48         521585       2014-10-17           OH
# 1                 228   42         342868       2006-06-27           IN
# 2                 134   29         687698       2000-09-06           OH
# 3                 256   41         227811       1990-05-25           IL
# 4                 228   44         367455       2014-06-06           IL
#
#   policy_csl  policy_deductable  policy_annual_premium  umbrella_limit  \
# 0    250/500               1000                1406.91               0
# 1    250/500               2000                1197.22         5000000
# 2    100/300               2000                1413.14         5000000
# 3    250/500               2000                1415.74         6000000
# 4   500/1000               1000                1583.91         6000000
#
#    insured_zip  ... property_claim vehicle_claim  auto_make auto_model  \
# ...

# %%
df_new['net_value_of_customer'] = df_new['total_premiums_paid'] - df_new['total_claim_amount']

# %%
df_new.head()
# Out:
#    months_as_customer  age  policy_number policy_bind_date policy_state  \
# 0                 328   48         521585       2014-10-17           OH
# 1                 228   42         342868       2006-06-27           IN
# 2                 134   29         687698       2000-09-06           OH
# 3                 256   41         227811       1990-05-25           IL
# 4                 228   44         367455       2014-06-06           IL
#
#   policy_csl  policy_deductable  policy_annual_premium  umbrella_limit  \
# 0    250/500               1000                1406.91               0
# 1    250/500               2000                1197.22         5000000
# 2    100/300               2000                1413.14         5000000
# 3    250/500               2000                1415.74         6000000
# 4   500/1000               1000                1583.91         6000000
#
#    insured_zip  ... vehicle_claim  auto_make auto_model auto_year  \
# ...

# %% [markdown]
# ## Saving the csv for late

# %%
df_new.to_csv('Workshop 7 Sayuri Goorun Advanced Features Claims Data.csv')

# %% [markdown]
# ## Go wild
#
# Go out a see what other features you can create that will be useful for our visualisations

# %%
df_new.columns
# Out:
# Index(['months_as_customer', 'age', 'policy_number', 'policy_bind_date',
#        'policy_state', 'policy_csl', 'policy_deductable',
#        'policy_annual_premium', 'umbrella_limit', 'insured_zip', 'insured_sex',
#        'insured_education_level', 'insured_occupation', 'insured_hobbies',
#        'insured_relationship', 'capital-gains', 'capital-loss',
#        'incident_date', 'incident_type', 'collision_type', 'incident_severity',
#        'authorities_contacted', 'incident_state', 'incident_city',
#        'incident_location', 'incident_hour_of_the_day',
#        'number_of_vehicles_involved', 'property_damage', 'bodily_injuries',
#        'witnesses', 'police_report_available', 'total_claim_amount',
#        'injury_claim', 'property_claim', 'vehicle_claim', 'auto_make',
#        'auto_model', 'auto_year', 'fraud_reported', 'ages_category',
#        'customer_category', 'Contract Years', 'total_premiums_paid',
#        'net_value_of_customer'],
#       dtype='object')

# %% [markdown]
# ## Sayuri Goorun - New Features

# %%
bins_age = [0, 30, 55, 100]
labels_age = ['Young Adult', 'Middle Aged', 'Elderly']

# %%
### Create age group column
df_new['age_group'] = pd.cut(df_new['age'], bins=bins_age, labels=labels_age)
df_new.head(2)
# Out:
#    months_as_customer  age  policy_number policy_bind_date policy_state  \
# 0                 328   48         521585       2014-10-17           OH
# 1                 228   42         342868       2006-06-27           IN
#
#   policy_csl  policy_deductable  policy_annual_premium  umbrella_limit  \
# 0    250/500               1000                1406.91               0
# 1    250/500               2000                1197.22         5000000
#
#    insured_zip  ... auto_make auto_model auto_year fraud_reported  \
# 0       466132  ...      Saab        92x      2004              Y
# 1       468176  ...  Mercedes       E400      2007              Y
#
#   ages_category  customer_category  Contract Years total_premiums_paid  \
# 0   Middle Aged   Long-Term Client       27.333333            38455.54
# 1   Middle Aged   Long-Term Client       19.000000            22747.18
#
#   net_value_of_customer    age_group
# 0             -33154.46  Middle Aged
# ...

# %%
# Calculate policy duration in years
df_new['policy_duration_years'] = (pd.to_datetime(df_new['incident_date']) - pd.to_datetime(df_new['policy_bind_date'])).dt.days / 365

# %%
df_new.head(2)
# Out:
#    months_as_customer  age  policy_number policy_bind_date policy_state  \
# 0                 328   48         521585       2014-10-17           OH
# 1                 228   42         342868       2006-06-27           IN
#
#   policy_csl  policy_deductable  policy_annual_premium  umbrella_limit  \
# 0    250/500               1000                1406.91               0
# 1    250/500               2000                1197.22         5000000
#
#    insured_zip  ... auto_model auto_year fraud_reported ages_category  \
# 0       466132  ...        92x      2004              Y   Middle Aged
# 1       468176  ...       E400      2007              Y   Middle Aged
#
#   customer_category  Contract Years  total_premiums_paid  \
# 0  Long-Term Client       27.333333             38455.54
# 1  Long-Term Client       19.000000             22747.18
#
#   net_value_of_customer    age_group policy_duration_years
# 0             -33154.46  Middle Aged              0.273973
# ...

# %%
# Calculate claim ratios
df_new['injury_claim_ratio'] = df_new['injury_claim'] / df_new['total_claim_amount']
df_new['property_claim_ratio'] = df_new['property_claim'] / df_new['total_claim_amount']
df_new['vehicle_claim_ratio'] = df_new['vehicle_claim'] / df_new['total_claim_amount']

# %%
df_new.head(2)
# Out:
#    months_as_customer  age  policy_number policy_bind_date policy_state  \
# 0                 328   48         521585       2014-10-17           OH
# 1                 228   42         342868       2006-06-27           IN
#
#   policy_csl  policy_deductable  policy_annual_premium  umbrella_limit  \
# 0    250/500               1000                1406.91               0
# 1    250/500               2000                1197.22         5000000
#
#    insured_zip  ... ages_category customer_category Contract Years  \
# 0       466132  ...   Middle Aged  Long-Term Client      27.333333
# 1       468176  ...   Middle Aged  Long-Term Client      19.000000
#
#   total_premiums_paid net_value_of_customer    age_group  \
# 0            38455.54             -33154.46  Middle Aged
# 1            22747.18              17677.18  Middle Aged
#
#    policy_duration_years injury_claim_ratio property_claim_ratio  \
# 0               0.273973           0.090909             0.181818
# ...

# %%
# Calculate vehicle age
df_new['vehicle_age'] = pd.to_datetime(df_new['incident_date']).dt.year - df_new['auto_year']

# %%
df_new.head(2)
# Out:
#    months_as_customer  age  policy_number policy_bind_date policy_state  \
# 0                 328   48         521585       2014-10-17           OH
# 1                 228   42         342868       2006-06-27           IN
#
#   policy_csl  policy_deductable  policy_annual_premium  umbrella_limit  \
# 0    250/500               1000                1406.91               0
# 1    250/500               2000                1197.22         5000000
#
#    insured_zip  ... customer_category Contract Years total_premiums_paid  \
# 0       466132  ...  Long-Term Client      27.333333            38455.54
# 1       468176  ...  Long-Term Client      19.000000            22747.18
#
#   net_value_of_customer    age_group  policy_duration_years  \
# 0             -33154.46  Middle Aged               0.273973
# 1              17677.18  Middle Aged               8.575342
#
#    injury_claim_ratio property_claim_ratio vehicle_claim_ratio vehicle_age
# ...

# %%
# Frequency encoding for auto_make
auto_make_freq = df_new['auto_make'].value_counts(normalize=True)
df_new['auto_make_freq'] = df_new['auto_make'].map(auto_make_freq)

df_new.head(2)
# Out:
#    months_as_customer  age  policy_number policy_bind_date policy_state  \
# 0                 328   48         521585       2014-10-17           OH
# 1                 228   42         342868       2006-06-27           IN
#
#   policy_csl  policy_deductable  policy_annual_premium  umbrella_limit  \
# 0    250/500               1000                1406.91               0
# 1    250/500               2000                1197.22         5000000
#
#    insured_zip  ... Contract Years total_premiums_paid net_value_of_customer  \
# 0       466132  ...      27.333333            38455.54             -33154.46
# 1       468176  ...      19.000000            22747.18              17677.18
#
#      age_group policy_duration_years  injury_claim_ratio  \
# 0  Middle Aged              0.273973            0.090909
# 1  Middle Aged              8.575342            0.153846
#
#    property_claim_ratio vehicle_claim_ratio vehicle_age auto_make_freq
# ...

# %%
# Frequency encoding for auto_model
auto_model_freq = df_new['auto_model'].value_counts(normalize=True)
df_new['auto_model_freq'] = df_new['auto_model'].map(auto_model_freq)

df_new.head(2)
# Out:
#    months_as_customer  age  policy_number policy_bind_date policy_state  \
# 0                 328   48         521585       2014-10-17           OH
# 1                 228   42         342868       2006-06-27           IN
#
#   policy_csl  policy_deductable  policy_annual_premium  umbrella_limit  \
# 0    250/500               1000                1406.91               0
# 1    250/500               2000                1197.22         5000000
#
#    insured_zip  ... total_premiums_paid net_value_of_customer    age_group  \
# 0       466132  ...            38455.54             -33154.46  Middle Aged
# 1       468176  ...            22747.18              17677.18  Middle Aged
#
#   policy_duration_years injury_claim_ratio  property_claim_ratio  \
# 0              0.273973           0.090909              0.181818
# 1              8.575342           0.153846              0.153846
#
#    vehicle_claim_ratio vehicle_age auto_make_freq auto_model_freq
# ...

# %%
# Binary encoding for insured_sex
df_new['insured_sex_binary'] = (df_new['insured_sex'] == 'M').astype(int)
df_new.head(2)
# Out:
#    months_as_customer  age  policy_number policy_bind_date policy_state  \
# 0                 328   48         521585       2014-10-17           OH
# 1                 228   42         342868       2006-06-27           IN
#
#   policy_csl  policy_deductable  policy_annual_premium  umbrella_limit  \
# 0    250/500               1000                1406.91               0
# 1    250/500               2000                1197.22         5000000
#
#    insured_zip  ... net_value_of_customer    age_group policy_duration_years  \
# 0       466132  ...             -33154.46  Middle Aged              0.273973
# 1       468176  ...              17677.18  Middle Aged              8.575342
#
#   injury_claim_ratio property_claim_ratio  vehicle_claim_ratio  vehicle_age  \
# 0           0.090909             0.181818             0.727273           11
# 1           0.153846             0.153846             0.692308            8
#
#   auto_make_freq auto_model_freq insured_sex_binary
# ...

# %% [markdown]
# ### Visuals

# %%
# Policy duration vs. fraud reported
plt.figure(figsize=(10, 6))
sns.boxplot(x='fraud_reported', y='policy_duration_years', data=df_new, palette='pastel')
plt.title('Policy Duration vs. Fraud Reported')
plt.xlabel('Fraud Reported')
plt.ylabel('Policy Duration (Years)')
plt.show()

# %%
# Vehicle age distribution
plt.figure(figsize=(8, 6))
df_new['vehicle_age'].plot(kind='hist', bins=20, color='orange')
plt.title('Distribution of Vehicle Ages')
plt.xlabel('Vehicle Age')
plt.ylabel('Count')
plt.show()

# %%
# Frequency of auto make
plt.figure(figsize=(10, 6))
df_new['auto_make'].value_counts().plot(kind='bar', color='skyblue')
plt.title('Frequency of Auto Make')
plt.xlabel('Auto Make')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.show()

# %%
# Age vs. total claim amount
plt.figure(figsize=(10, 6))
sns.scatterplot(x='age', y='total_claim_amount', data=df_new, hue='fraud_reported', palette='viridis')
plt.title('Age vs. Total Claim Amount')
plt.xlabel('Age')
plt.ylabel('Total Claim Amount')
plt.legend(title='Fraud Reported', loc='upper right')
plt.show()

# %%
# Correlation heatmap
plt.figure(figsize=(15, 14))
sns.heatmap(df_new.corr(), annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Heatmap')
plt.show()

# %%
# Fraud reported distribution
plt.figure(figsize=(8, 6))
df_new['fraud_reported'].value_counts().plot(kind='bar', color=['skyblue', 'salmon'])
plt.title('Distribution of Fraud Reported')
plt.xlabel('Fraud Reported')
plt.ylabel('Count')
plt.xticks(rotation=0)
plt.show()

# %%
# Incident severity vs. total claim amount
plt.figure(figsize=(10, 6))
sns.boxplot(x='incident_severity', y='total_claim_amount', data=df_new, palette='muted')
plt.title('Incident Severity vs. Total Claim Amount')
plt.xlabel('Incident Severity')
plt.ylabel('Total Claim Amount')
plt.show()

# %%
# Customer categories distribution
plt.figure(figsize=(8, 6))
df_new['customer_category'].value_counts().plot(kind='bar', color='lightgreen')
plt.title('Distribution of Customer Categories')
plt.xlabel('Customer Category')
plt.ylabel('Count')
plt.xticks(rotation=0)
plt.show()

# %%
# Policy duration vs. total premiums paid
plt.figure(figsize=(10, 6))
sns.scatterplot(x='policy_duration_years', y='total_premiums_paid', data=df_new, hue='fraud_reported', palette='Set2')
plt.title('Policy Duration vs. Total Premiums Paid')
plt.xlabel('Policy Duration (Years)')
plt.ylabel('Total Premiums Paid')
plt.legend(title='Fraud Reported', loc='upper left')
plt.show()

# %%
df_new.columns
# Out:
# Index(['months_as_customer', 'age', 'policy_number', 'policy_bind_date',
#        'policy_state', 'policy_csl', 'policy_deductable',
#        'policy_annual_premium', 'umbrella_limit', 'insured_zip', 'insured_sex',
#        'insured_education_level', 'insured_occupation', 'insured_hobbies',
#        'insured_relationship', 'capital-gains', 'capital-loss',
#        'incident_date', 'incident_type', 'collision_type', 'incident_severity',
#        'authorities_contacted', 'incident_state', 'incident_city',
#        'incident_location', 'incident_hour_of_the_day',
#        'number_of_vehicles_involved', 'property_damage', 'bodily_injuries',
#        'witnesses', 'police_report_available', 'total_claim_amount',
#        'injury_claim', 'property_claim', 'vehicle_claim', 'auto_make',
#        'auto_model', 'auto_year', 'fraud_reported', 'ages_category',
#        'customer_category', 'Contract Years', 'total_premiums_paid',
# ...
